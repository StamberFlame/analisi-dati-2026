# %% [markdown]
# # Generatori di numeri pseudocasuali in python
#
# Cominciamo ad utilizzare il modulo ```random``` che contiene un algoritmo per la generazione di numeri casuali uniformi tra 0 e 1.
#
# Nel seguito introdurremo altre librerie che contengono generatori con distribuzioni non uniformi, dopo che avremo definito meglio cosa si intende per *distribuzione*.
#
# La documentazione si trova facilmente con Google. Di seguito alcuni link:
# * <a href="https://docs.python.org/3/library/random.html">random</a> (python.org)
# * <a href="https://www.w3schools.com/python/module_random.asp">Python Random Module</a> (W3School)

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
help(random.random)
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).

# %% [markdown]
# Da notare: usando lo stesso *seed* la sequenza è riproducibile.
#
# Se non si inizializza il *seed*, viene inizializzato dall'orario di sistema.

# %%
random.seed(12345)

# %%
for i in range(10):
    print(random.random())
# Out:
# 0.41661987254534116
# 0.010169169457068361
# 0.8252065092537432
# 0.2986398551995928
# 0.3684116894884757
# 0.19366134904507426
# 0.5660081687288613
# 0.1616878239293682
# 0.12426688428353017
# 0.4329362680099159

# %% [markdown]
# Per generare numeri casuali da un minimo $a$ ad un massimo $b$ basta:
# * generare un numero casuale con ```random.random()```
# * moltiplicare per $b-a$
# * sommare $a$
# Il risultato sarà compreso in $[a,\,b)$

# %%
def rnd_ab(a, b):
    return a + (b - a)*random.random()
for i in range(10):
    print(rnd_ab(-2, 2))
# Out:
# 0.24831395230337172
# -1.3026257571050728
# 0.21288434227731923
# -0.5803944546536051
# 1.8322591403981945
# -1.6348236044930595
# 1.9145599822816401
# -0.351522428242796
# 0.015741472440149895
# -1.4074153242792433

# %% [markdown]
# ...ma questa funzionalità si ottiene dando $a$ e $b$ come argomenti della funzione ```random```:

# %%
for i in range(10):
    print(random.uniform(-2, 2))
# Out:
# 0.8758685612035402
# -1.2401144851127186
# -0.6337582969057913
# -1.9059151274311978
# -0.6419289104083172
# 1.8699298355194856
# 1.9151938167426272
# 0.9781201605641385
# -1.9861815569796177
# 1.7609540123909713

# %% [markdown]
# ... a questo punto, abbiamo degli strumenti per generare numeri casuali e simulare, quindi, i risultati di un esperimento.
#
# Però, dobbiamo definire meglio cosa significa:
# * Probabilità
# * Distrubuzione di probabilità

# %% [markdown]
# # Spunti per esercizi
#
# Generare grafici delle distribuzioni d numeri casuali generati con il modulo ```random```:
#
# * uniformi tra 0 e 1, come dalla funzione ```random()```
# * uniformi tra due valori $a$ e $b$, come indicato sopra
# * graficare la distribuzione di $x^2$, dove $x$ è un numero random uniformemente distribuito
# * graficare la distribuzione di $e^x$, $1/x$, e $\mathrm{log}(x)$

# %%
random.seed(456)
num = 100000
seq = [random.random() for i in range(num)]
nbins = 100
fig, ax = plt.subplots(figsize=(10, 4))
n, bins, patches = ax.hist(seq, nbins, range=(0, 1))
avg = float(num)/nbins
ax.plot((0, 1),(avg, avg), '--')
ax.set_xlabel('$x$')
ax.set_ylabel(r'$\Delta n$')
plt.show()

# %%
random.seed(456)
num = 100000
a, b = -1, 3
seq = [a + (b - a) * random.random() for i in range(num)]
nbins = 100
fig, ax = plt.subplots(figsize=(10, 4))
n, bins, patches = ax.hist(seq, nbins, range=(a, b))
avg = float(num)/nbins
ax.plot((a, b),(avg, avg), '--')
ax.set_xlabel('$x$')
ax.set_ylabel(r'$\Delta n$')
plt.show()

# %% [markdown]
# La densità di valori $x$ sarà uniforme, ossia:
# $$\frac{\mathrm{d}n}{\mathrm{d}x} = \frac{N}{n_{\mathrm{bins}, x}}$$
#
# $$\rho(x) = \frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}x} = 1\ , \ \ \ \int_0^1 \rho(x)\,\mathrm{d}x = 1$$
#
# Trasformando $x$ in $y$:
# $$y = x^2$$
#
# posso trasformare la densità di valori in $x$ nell'equivalente densità di valori in $y$:
# $$\rho(y) = \frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}y} = \frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}x^2} =\frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}x} \frac{\mathrm{d}x}{\mathrm{d}x^2} =  \frac{1}{2x} = \frac{1}{2\sqrt{y}}$$
#
# $$\frac{\mathrm{d}n}{\mathrm{d}y} = N \rho(y) \ \ \implies\ \ \mathrm{d}n = N \rho(y)\,\mathrm{d}y $$

# %%
random.seed(456)
num = 100000
seq = [random.random()**2 for i in range(num)]
nbins = 100
fig, ax = plt.subplots(figsize=(10, 4))
n, bins, patches = ax.hist(seq, nbins, range=(0, 1))
avg = float(num)/nbins
xs = (bins[:nbins] + bins[1:])/2
ys = num / (2 * nbins * np.sqrt(xs))
ax.plot(xs, ys, '--')
ax.set_xlabel('$x^2$')
ax.set_ylabel(r'$\Delta n$')
plt.show()

# %% [markdown]
# La densità di valori $x$ sarà uniforme, ossia:
# $$\frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}x} = 1$$
#
# Trasformando $x$ in $y$:
# $$y = \frac{1}{x}$$
#
# posso trasformare la densità di valori in $x$ nell'equivalente densità di valori in $y$:
# $$\rho(y) = \frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}y} = \frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}x^{-1}} =\frac{1}{N}\frac{\mathrm{d}n}{\mathrm{d}x}\left|\frac{\mathrm{d}x}{\mathrm{d}x^{-1}}\right| = \frac{1}{x^{2}} = y^{-2}$$
#
# Devo verificare che:
#
# $$\int_1^\infty \frac{\mathrm{d}x}{x^2} = 1$$
#
# Nel plot devo visualizzare:
#
# $$\mathrm{d}n = N \rho(y)\,\mathrm{d} y$$

# %%
random.seed(456)
num = 100000
seq = [1.0 / random.random() for i in range(num)]
nbins = 100
fig, ax = plt.subplots(figsize=(10, 4))
n, bins, patches = ax.hist(seq, nbins, range=(1, 1000))
avg = float(num)/nbins
xs = (bins[:nbins] + bins[1:])/2
dx = bins[1] - bins[0]
ys = num * dx / xs**2
ax.plot(xs, ys, '--')
ax.set_xlabel('$1/x$')
ax.set_ylabel(r'$\Delta n$')
ax.set_yscale('log')
plt.show()
